# %%
import pickle

# %%
loaded_model = pickle.load(open('regression_assign_randomForest_final.sav','rb'))
result=loaded_model.predict([[25,29,2,0,0]])
result
# Out:
# C:\Users\subas\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([4476.2216785])
